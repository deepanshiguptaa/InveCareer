# %% [markdown]
# # STUDENT PERFORMANCE ANALYSIS

# %% [markdown]
# # PROBLEM STATEMENT
# Utilize a dataset containing student exam scores, demographic information, and study habits.
# Analyze the distribution of exam scores and identify trends. Investigate correlations between study time, demographic factors, and exam performance. Visualize the data using bar charts, scatter plots, and histograms.
# Provide recommendations for improving student performance based on the analysis.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv(r"C:\Users\admin\Downloads\Student_performance_data _.csv")
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
df.describe(include='all').T
# Out:
#                     count         mean         std          min          25%  \
# StudentID          2392.0  2196.500000  690.655244  1001.000000  1598.750000
# Age                2392.0    16.468645    1.123798    15.000000    15.000000
# Gender             2392.0     0.510870    0.499986     0.000000     0.000000
# Ethnicity          2392.0     0.877508    1.028476     0.000000     0.000000
# ParentalEducation  2392.0     1.746237    1.000411     0.000000     1.000000
# StudyTimeWeekly    2392.0     9.771992    5.652774     0.001057     5.043079
# Absences           2392.0    14.541388    8.467417     0.000000     7.000000
# Tutoring           2392.0     0.301421    0.458971     0.000000     0.000000
# ParentalSupport    2392.0     2.122074    1.122813     0.000000     1.000000
# Extracurricular    2392.0     0.383361    0.486307     0.000000     0.000000
# Sports             2392.0     0.303512    0.459870     0.000000     0.000000
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis and Visualisation

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['GPA'], kde=True, bins=30, color='blue')
plt.title('Distribution of GPA')
plt.xlabel('GPA')
plt.ylabel('Frequency')
plt.show()

# %% [raw]
# Above graph shows that most of the students scored GPA greater than 1.5 with most ranging between 1.5 and 2.5 and the no. decreasing as it reached 4.0.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='GPA', data=df, palette='Set2')
plt.title('GPA by Gender')
plt.xlabel('Gender')
plt.ylabel('GPA')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16956\2646191905.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Gender', y='GPA', data=df, palette='Set2')

# %% [raw]
# Above box plot shows that median GPA value of males is greater than females though they have the same minimum and maximum value.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='ParentalEducation', y='GPA', data=df, palette='Set3')
plt.title('GPA by Parental Education Level')
plt.xlabel('Parental Education Level')
plt.ylabel('GPA')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16956\853625335.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='ParentalEducation', y='GPA', data=df, palette='Set3')

# %% [raw]
# Children of the parents educated upto 0,1 and 2 level have scored better GPA as compared to level 3 and 4.

# %%
plt.figure(figsize=(14, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='StudyTimeWeekly', y='GPA', data=df, hue='Gender', palette='Set1')
plt.title('Study Time vs GPA')
plt.xlabel('Study Time Weekly (hours)')
plt.ylabel('GPA')
plt.show()

# %% [raw]
# More study time means better GPA.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Absences', y='GPA', data=df, hue='Gender', palette='Set2')
plt.title('Absences vs GPA')
plt.xlabel('Number of Absences')
plt.ylabel('GPA')
plt.show()

# %% [raw]
# Students having less absences scored better than those having more absences.

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. Most of the students scored GPA greater than 1.5 with most ranging between 1.5 and 2.5 and the no. decreasing as it reached 4.0.
# 2. Median GPA value of males is greater than females.
# 3. Children of the parents educated upto 0,1 and 2 level have scored better GPA as compared to level 3 and 4.
# 4. More study time means better GPA.
# 5. Students having less absences scored better than those having more absences.
